# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("uvvis_rods1_Isadora.txt",skiprows=43,encoding='latin-1',sep=",")

# %%
plt.figure(figsize=(12,9))
plt.grid()
plt.plot(df['Wavelength (nm)'],df['Absorbance'])
plt.xlabel("Comprimento de Onda(nm)",fontweight='bold',fontsize=14)
plt.ylabel("Absorbância",fontweight='bold',fontsize=14)
plt.xticks(fontsize=12,fontweight='bold') 
plt.yticks(fontsize=12,fontweight='bold') 
plt.xlim((200,1200))
plt.ylim(0,0.6)

plt.show()
